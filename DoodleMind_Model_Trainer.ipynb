# %%
import os,requests
def download(url):
    get_response = requests.get(url,stream=True)
    file_name  = "data.zip"
    with open(file_name, 'wb') as f:
        for chunk in get_response.iter_content(chunk_size=1024):
            if chunk:
                f.write(chunk)

download("https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/10200/868375/upload/train_simplified.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1744049325&Signature=WOYm2xtl6DMWm4HCEEzXH94yueZvxywCpsKrf0nTn0D7%2FOrdVWU1JvRdvPXsoGV8ArR333S%2FL3525YvBLrRayjXjd%2Fhx0%2FDHKgXFIJqMhRkVk4AxvZC65%2FZ1ru0Bu7wI7cQJ7V67sELGyLbVszqF%2FhxjTYPVKwekB%2FgxabFoJCgArZ%2FfNrqvMevYsvRJoona56J%2FEKkb802mXclNEafFaCoN6kQPsM6gUBxlQuPi85pwC48%2FL0YL09qJatbpRoy%2BnSX46cpanpJcMffkuVjnhwDf1sUdPzvVSKFYCm0AmHi8aD6jEj3t5hRGpdPDjCyn1n96C4K4kKaoTNWR%2B9PnuA%3D%3D&response-content-disposition=attachment%3B+filename%3Dtrain_simplified.zip")

# %%
import zipfile
with zipfile.ZipFile('./data.zip', 'r') as zip_ref:
    zip_ref.extractall('./input')

# %%
pip install mlflow
# Out:
# Collecting mlflow
#   Downloading mlflow-2.21.3-py3-none-any.whl.metadata (30 kB)
# Collecting mlflow-skinny==2.21.3 (from mlflow)
#   Downloading mlflow_skinny-2.21.3-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.11/dist-packages (from mlflow) (3.1.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /usr/local/lib/python3.11/dist-packages (from mlflow) (3.1.6)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.11/dist-packages (from mlflow) (3.7)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.11/dist-packages (from mlflow) (3.10.0)
# Requirement already satisfied: numpy<3 in /usr/local/lib/python3.11/dist-packages (from mlflow) (2.0.2)
# Requirement already satisfied: pandas<3 in /usr/local/lib/python3.11/dist-packages (from mlflow) (2.2.2)
# Requirement already satisfied: pyarrow<20,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow) (18.1.0)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.11/dist-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in /usr/local/lib/python3.11/dist-packages (from mlflow) (1.14.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow) (2.0.40)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (3.1.1)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==2.21.3->mlflow)
#   Downloading databricks_sdk-0.49.0-py3-none-any.whl.metadata (38 kB)
# Collecting fastapi<1 (from mlflow-skinny==2.21.3->mlflow)
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (3.1.44)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (8.6.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (1.31.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (1.31.1)
# Requirement already satisfied: packaging<25 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (24.2)
# Requirement already satisfied: protobuf<6,>=3.12.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (5.29.4)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (2.11.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.21.3->mlflow) (4.13.0)
# Collecting uvicorn<1 (from mlflow-skinny==2.21.3->mlflow)
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic!=1.10.0,<2->mlflow) (1.1.3)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from docker<8,>=4.0.0->mlflow) (2.3.0)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow) (1.9.0)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from graphene<4->mlflow) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2<4,>=2.11->mlflow) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.1.1)
# Requirement already satisfied: google-auth~=2.0 in /usr/local/lib/python3.11/dist-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.3->mlflow) (2.38.0)
# Collecting starlette<0.47.0,>=0.40.0 (from fastapi<1->mlflow-skinny==2.21.3->mlflow)
#   Downloading starlette-0.46.1-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.21.3->mlflow) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.21.3->mlflow) (3.21.0)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.21.3->mlflow) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.21.3->mlflow) (0.52b1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.21.3->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.21.3->mlflow) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.21.3->mlflow) (0.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==2.21.3->mlflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==2.21.3->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==2.21.3->mlflow) (2025.1.31)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn<1->mlflow-skinny==2.21.3->mlflow) (0.14.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.21.3->mlflow) (1.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.21.3->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.3->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.3->mlflow) (4.9)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.21.3->mlflow) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.21.3->mlflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.3->mlflow) (0.6.1)
# Downloading mlflow-2.21.3-py3-none-any.whl (28.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.2/28.2 MB 57.4 MB/s eta 0:00:00
# Downloading mlflow_skinny-2.21.3-py3-none-any.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 78.9 MB/s eta 0:00:00
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 25.8 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 19.9 MB/s eta 0:00:00
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 14.4 MB/s eta 0:00:00
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 10.4 MB/s eta 0:00:00
# Downloading databricks_sdk-0.49.0-py3-none-any.whl (683 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 684.0/684.0 kB 57.5 MB/s eta 0:00:00
# Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 12.5 MB/s eta 0:00:00
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 24.7 MB/s eta 0:00:00
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 8.2 MB/s eta 0:00:00
# Downloading starlette-0.46.1-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 9.2 MB/s eta 0:00:00
# Installing collected packages: uvicorn, gunicorn, graphql-core, starlette, graphql-relay, docker, alembic, graphene, fastapi, databricks-sdk, mlflow-skinny, mlflow
# Successfully installed alembic-1.15.2 databricks-sdk-0.49.0 docker-7.1.0 fastapi-0.115.12 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 gunicorn-23.0.0 mlflow-2.21.3 mlflow-skinny-2.21.3 starlette-0.46.1 uvicorn-0.34.0

# %%
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import json
import os
import datetime as dt
from tqdm import tqdm
import pandas as pd
import numpy as np
import mlflow

# %%
def f2cat(filename: str) -> str:
    return filename.split('.')[0]

class Simplified():
    def __init__(self, input_path='./input'):
        self.input_path = input_path

    def list_all_categories(self):
        files = os.listdir(os.path.join(self.input_path))
        return sorted([f2cat(f) for f in files], key=str.lower)

    def read_training_csv(self, category, nrows=None, usecols=None, drawing_transform=False):
        df = pd.read_csv(os.path.join(self.input_path, category + '.csv'),
                         nrows=nrows, parse_dates=['timestamp'], usecols=usecols)
        if drawing_transform:
            df['drawing'] = df['drawing'].apply(json.loads)
        return df

# %%
start = dt.datetime.now()
s = Simplified('./input')
NCSVS = 100
categories = s.list_all_categories()
print(len(categories))
# Out:
# 340

# %%
for y, cat in tqdm(enumerate(categories)):
    df = s.read_training_csv(cat, nrows=30000)
    df['y'] = y
    df['cv'] = (df.key_id // 10 ** 7) % NCSVS
    for k in range(NCSVS):
        filename = 'train_k{}.csv'.format(k)
        chunk = df[df.cv == k]
        chunk = chunk.drop(['key_id'], axis=1)
        if y == 0:
            chunk.to_csv(filename, index=False)
        else:
            chunk.to_csv(filename, mode='a', header=False, index=False)
# Out:
# 321it [02:49,  1.96it/s]C:\Users\madha\AppData\Local\Temp\ipykernel_12432\3078944577.py:13: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(os.path.join(self.input_path, category + '.csv'),
# 340it [02:59,  1.90it/s]

# %%
for k in tqdm(range(NCSVS)):
    filename = 'train_k{}.csv'.format(k)
    if os.path.exists(filename):
        df = pd.read_csv(filename)
        df['rnd'] = np.random.rand(len(df))
        df = df.sort_values(by='rnd').drop('rnd', axis=1)
        df.to_csv(filename + '.gz', compression='gzip', index=False)
        os.remove(filename)
print(df.shape)
# Out:
# 100%|██████████| 100/100 [1:51:09<00:00, 66.70s/it]
# (102042, 7)

# %%
end = dt.datetime.now()
print('Latest run {}.\nTotal time {}s'.format(end, (end - start).seconds))
# Out:
# Latest run 2025-04-04 19:55:07.925595.
# Total time 6848s

# %%
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import os
import json
import datetime as dt
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [16, 10]
plt.rcParams['font.size'] = 14
import seaborn as sns
import cv2
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation
from tensorflow.keras.metrics import categorical_accuracy, top_k_categorical_accuracy, categorical_crossentropy
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.applications.mobilenet import preprocess_input
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
start = dt.datetime.now()

# %%
DP_DIR = './'
INPUT_DIR = '../input/'

BASE_SIZE = 256
NCSVS = 74
NCATS = 340
np.random.seed(seed=1987)
tf.random.set_seed(1987)  # Correct method in TF 2.x

def f2cat(filename: str) -> str:
    return filename.split('.')[0]

def list_all_categories():
    files = os.listdir(os.path.join(INPUT_DIR))
    return sorted([f2cat(f) for f in files], key=str.lower)

# %%
def apk(actual, predicted, k=3):
    """
    Source: https://github.com/benhamner/Metrics/blob/master/Python/ml_metrics/average_precision.py
    """
    if len(predicted) > k:
        predicted = predicted[:k]
    score = 0.0
    num_hits = 0.0
    for i, p in enumerate(predicted):
        if p in actual and p not in predicted[:i]:
            num_hits += 1.0
            score += num_hits / (i + 1.0)
    if not actual:
        return 0.0
    return score / min(len(actual), k)

def mapk(actual, predicted, k=3):
    """
    Source: https://github.com/benhamner/Metrics/blob/master/Python/ml_metrics/average_precision.py
    """
    return np.mean([apk(a, p, k) for a, p in zip(actual, predicted)])

def preds2catids(predictions):
    return pd.DataFrame(np.argsort(-predictions, axis=1)[:, :3], columns=['a', 'b', 'c'])

def top_3_accuracy(y_true, y_pred):
    return top_k_categorical_accuracy(y_true, y_pred, k=3)

# %%
STEPS = 800
EPOCHS = 10
size = 64
batchsize = 680

# %%
model = MobileNet(input_shape=(size, size, 1), alpha=1., weights=None, classes=NCATS)
model.compile(optimizer=Adam(learning_rate=0.002), loss='categorical_crossentropy',
              metrics=[categorical_crossentropy, categorical_accuracy, top_3_accuracy])
print(model.summary())
# Out:
# Model: "mobilenet_1.00_64"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 64, 64, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1 (Conv2D)                       │ (None, 32, 32, 32)          │             288 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1_bn (BatchNormalization)        │ (None, 32, 32, 32)          │             128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1_relu (ReLU)                    │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_1 (DepthwiseConv2D)          │ (None, 32, 32, 32)          │             288 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_1_bn (BatchNormalization)    │ (None, 32, 32, 32)          │             128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_1_relu (ReLU)                │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_1 (Conv2D)                   │ (None, 32, 32, 64)          │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_1_bn (BatchNormalization)    │ (None, 32, 32, 64)          │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_1_relu (ReLU)                │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pad_2 (ZeroPadding2D)           │ (None, 33, 33, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_2 (DepthwiseConv2D)          │ (None, 16, 16, 64)          │             576 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_2_bn (BatchNormalization)    │ (None, 16, 16, 64)          │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_2_relu (ReLU)                │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_2 (Conv2D)                   │ (None, 16, 16, 128)         │           8,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_2_bn (BatchNormalization)    │ (None, 16, 16, 128)         │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_2_relu (ReLU)                │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_3 (DepthwiseConv2D)          │ (None, 16, 16, 128)         │           1,152 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_3_bn (BatchNormalization)    │ (None, 16, 16, 128)         │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_3_relu (ReLU)                │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_3 (Conv2D)                   │ (None, 16, 16, 128)         │          16,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_3_bn (BatchNormalization)    │ (None, 16, 16, 128)         │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_3_relu (ReLU)                │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pad_4 (ZeroPadding2D)           │ (None, 17, 17, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_4 (DepthwiseConv2D)          │ (None, 8, 8, 128)           │           1,152 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_4_bn (BatchNormalization)    │ (None, 8, 8, 128)           │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_4_relu (ReLU)                │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_4 (Conv2D)                   │ (None, 8, 8, 256)           │          32,768 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_4_bn (BatchNormalization)    │ (None, 8, 8, 256)           │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_4_relu (ReLU)                │ (None, 8, 8, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_5 (DepthwiseConv2D)          │ (None, 8, 8, 256)           │           2,304 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_5_bn (BatchNormalization)    │ (None, 8, 8, 256)           │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_5_relu (ReLU)                │ (None, 8, 8, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_5 (Conv2D)                   │ (None, 8, 8, 256)           │          65,536 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_5_bn (BatchNormalization)    │ (None, 8, 8, 256)           │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_5_relu (ReLU)                │ (None, 8, 8, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pad_6 (ZeroPadding2D)           │ (None, 9, 9, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_6 (DepthwiseConv2D)          │ (None, 4, 4, 256)           │           2,304 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_6_bn (BatchNormalization)    │ (None, 4, 4, 256)           │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_6_relu (ReLU)                │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_6 (Conv2D)                   │ (None, 4, 4, 512)           │         131,072 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_6_bn (BatchNormalization)    │ (None, 4, 4, 512)           │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_6_relu (ReLU)                │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_7 (DepthwiseConv2D)          │ (None, 4, 4, 512)           │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_7_bn (BatchNormalization)    │ (None, 4, 4, 512)           │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_7_relu (ReLU)                │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_7 (Conv2D)                   │ (None, 4, 4, 512)           │         262,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_7_bn (BatchNormalization)    │ (None, 4, 4, 512)           │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_7_relu (ReLU)                │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_8 (DepthwiseConv2D)          │ (None, 4, 4, 512)           │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_8_bn (BatchNormalization)    │ (None, 4, 4, 512)           │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_8_relu (ReLU)                │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_8 (Conv2D)                   │ (None, 4, 4, 512)           │         262,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_8_bn (BatchNormalization)    │ (None, 4, 4, 512)           │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_8_relu (ReLU)                │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_9 (DepthwiseConv2D)          │ (None, 4, 4, 512)           │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_9_bn (BatchNormalization)    │ (None, 4, 4, 512)           │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_9_relu (ReLU)                │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_9 (Conv2D)                   │ (None, 4, 4, 512)           │         262,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_9_bn (BatchNormalization)    │ (None, 4, 4, 512)           │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_9_relu (ReLU)                │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_10 (DepthwiseConv2D)         │ (None, 4, 4, 512)           │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_10_bn (BatchNormalization)   │ (None, 4, 4, 512)           │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_10_relu (ReLU)               │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_10 (Conv2D)                  │ (None, 4, 4, 512)           │         262,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_10_bn (BatchNormalization)   │ (None, 4, 4, 512)           │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_10_relu (ReLU)               │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_11 (DepthwiseConv2D)         │ (None, 4, 4, 512)           │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_11_bn (BatchNormalization)   │ (None, 4, 4, 512)           │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_11_relu (ReLU)               │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_11 (Conv2D)                  │ (None, 4, 4, 512)           │         262,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_11_bn (BatchNormalization)   │ (None, 4, 4, 512)           │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_11_relu (ReLU)               │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pad_12 (ZeroPadding2D)          │ (None, 5, 5, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_12 (DepthwiseConv2D)         │ (None, 2, 2, 512)           │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_12_bn (BatchNormalization)   │ (None, 2, 2, 512)           │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_12_relu (ReLU)               │ (None, 2, 2, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_12 (Conv2D)                  │ (None, 2, 2, 1024)          │         524,288 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_12_bn (BatchNormalization)   │ (None, 2, 2, 1024)          │           4,096 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_12_relu (ReLU)               │ (None, 2, 2, 1024)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_13 (DepthwiseConv2D)         │ (None, 2, 2, 1024)          │           9,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_13_bn (BatchNormalization)   │ (None, 2, 2, 1024)          │           4,096 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_13_relu (ReLU)               │ (None, 2, 2, 1024)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_13 (Conv2D)                  │ (None, 2, 2, 1024)          │       1,048,576 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_13_bn (BatchNormalization)   │ (None, 2, 2, 1024)          │           4,096 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_13_relu (ReLU)               │ (None, 2, 2, 1024)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1, 1, 1024)          │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1, 1, 1024)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_preds (Conv2D)                  │ (None, 1, 1, 340)           │         348,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape_2 (Reshape)                  │ (None, 340)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ predictions (Activation)             │ (None, 340)                 │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,576,788 (13.64 MB)
#  Trainable params: 3,554,900 (13.56 MB)
#  Non-trainable params: 21,888 (85.50 KB)
# None

# %%
def draw_cv2(raw_strokes, size=256, lw=6, time_color=True):
    img = np.zeros((BASE_SIZE, BASE_SIZE), np.uint8)
    for t, stroke in enumerate(raw_strokes):
        for i in range(len(stroke[0]) - 1):
            color = 255 - min(t, 10) * 13 if time_color else 255
            _ = cv2.line(img, (stroke[0][i], stroke[1][i]),
                         (stroke[0][i + 1], stroke[1][i + 1]), color, lw)
    if size != BASE_SIZE:
        return cv2.resize(img, (size, size))
    else:
        return img

def image_generator_xd(size, batchsize, ks, lw=6, time_color=True):
    while True:
        for k in np.random.permutation(ks):
            filename = os.path.join(DP_DIR, 'train_k{}.csv.gz'.format(k))
            for df in pd.read_csv(filename, chunksize=batchsize):
                df['drawing'] = df['drawing'].apply(json.loads)
                x = np.zeros((len(df), size, size, 1))
                for i, raw_strokes in enumerate(df.drawing.values):
                    x[i, :, :, 0] = draw_cv2(raw_strokes, size=size, lw=lw,
                                             time_color=time_color)
                x = preprocess_input(x).astype(np.float32)
                y = keras.utils.to_categorical(df.y, num_classes=NCATS)
                yield x, y

def df_to_image_array_xd(df, size, lw=6, time_color=True):
    df['drawing'] = df['drawing'].apply(json.loads)
    x = np.zeros((len(df), size, size, 1))
    for i, raw_strokes in enumerate(df.drawing.values):
        x[i, :, :, 0] = draw_cv2(raw_strokes, size=size, lw=lw, time_color=time_color)
    x = preprocess_input(x).astype(np.float32)
    return x

# %%
valid_df = pd.read_csv(os.path.join(DP_DIR, 'train_k{}.csv.gz'.format(NCSVS - 1)), nrows=34000)
x_valid = df_to_image_array_xd(valid_df, size)
y_valid = keras.utils.to_categorical(valid_df.y, num_classes=NCATS)
print(x_valid.shape, y_valid.shape)
print('Validation array memory {:.2f} GB'.format(x_valid.nbytes / 1024.**3 ))
# Out:
# (34000, 64, 64, 1) (34000, 340)
# Validation array memory 0.52 GB

# %%
train_datagen = image_generator_xd(size=size, batchsize=batchsize, ks=range(NCSVS - 1))

# %%
x, y = next(train_datagen)
n = 8
fig, axs = plt.subplots(nrows=n, ncols=n, sharex=True, sharey=True, figsize=(12, 12))
for i in range(n**2):
    ax = axs[i // n, i % n]
    (-x[i]+1)/2
    ax.imshow((-x[i, :, :, 0] + 1)/2, cmap=plt.cm.gray)
    ax.axis('off')
plt.tight_layout()
fig.savefig('gs.png', dpi=300)
plt.show();

# %%
# %%timeit
x, y = next(train_datagen)
# Out:
# 102 ms ± 22.6 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
import mlflow
# Function to train and log model
def train_and_log_model(model, model_name):
    with mlflow.start_run():
        callbacks = [
            ReduceLROnPlateau(monitor='val_top_3_accuracy', factor=0.75, patience=3, min_delta=0.001,
                                  mode='max', min_lr=1e-5, verbose=1),
            ModelCheckpoint('doodlemind_model.weights.h5', monitor='val_top_3_accuracy', mode='max', save_best_only=True,
                            save_weights_only=True, save_freq='epoch', verbose=1),
            EarlyStopping(monitor='val_top_3_accuracy', min_delta=0.001, patience=5,
                          restore_best_weights=True, mode='max', verbose=1)
        ]
        # Train model
        hists = []
        hist = model.fit(
        train_datagen, steps_per_epoch=STEPS, epochs=3, verbose=1,
        validation_data=(x_valid, y_valid),
        callbacks = callbacks
        )
        hists.append(hist)

        # Make predictions
        valid_predictions = model.predict(x_valid, batch_size=128, verbose=1)

        y_true = valid_df['y'].values

        map3 = mapk(valid_df[['y']].values, preds2catids(valid_predictions).values)

        y_pred_top1 = np.argmax(valid_predictions, axis=1)

        # Classification Metrics
        accuracy = accuracy_score(y_true, y_pred_top1)
        print("Accuracy:", accuracy)

        print("Classification Report:")
        print(classification_report(y_true, y_pred_top1))

        print("Confusion Matrix:")
        print(confusion_matrix(y_true, y_pred_top1))

        # Optional: Log to MLflow

        mlflow.log_metric("MAP3", map3)
        mlflow.log_metric("Top1 Accuracy", accuracy)
        mlflow.sklearn.log_model(model, model_name)

        print(f"{model_name} logged with accuracy: {accuracy:.4f}")

# %%
#To start mlFlow
train_and_log_model(model, "Mobilenet")
# Out:
# Epoch 1/3
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - categorical_accuracy: 0.6746 - categorical_crossentropy: 1.2893 - loss: 1.2893 - top_3_accuracy: 0.8496
# Epoch 1: val_top_3_accuracy improved from -inf to 0.42326, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 241s 301ms/step - categorical_accuracy: 0.6746 - categorical_crossentropy: 1.2893 - loss: 1.2893 - top_3_accuracy: 0.8496 - val_categorical_accuracy: 0.2609 - val_categorical_crossentropy: 4.0878 - val_loss: 4.0878 - val_top_3_accuracy: 0.4233 - learning_rate: 0.0020
# Epoch 2/3
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - categorical_accuracy: 0.6867 - categorical_crossentropy: 1.2350 - loss: 1.2350 - top_3_accuracy: 0.8574
# Epoch 2: val_top_3_accuracy improved from 0.42326 to 0.79974, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 243s 304ms/step - categorical_accuracy: 0.6867 - categorical_crossentropy: 1.2349 - loss: 1.2349 - top_3_accuracy: 0.8574 - val_categorical_accuracy: 0.5956 - val_categorical_crossentropy: 1.6270 - val_loss: 1.6270 - val_top_3_accuracy: 0.7997 - learning_rate: 0.0020
# Epoch 3/3
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - categorical_accuracy: 0.6975 - categorical_crossentropy: 1.1892 - loss: 1.1892 - top_3_accuracy: 0.8646
# Epoch 3: val_top_3_accuracy improved from 0.79974 to 0.83526, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 210s 263ms/step - categorical_accuracy: 0.6975 - categorical_crossentropy: 1.1892 - loss: 1.1892 - top_3_accuracy: 0.8647 - val_categorical_accuracy: 0.6501 - val_categorical_crossentropy: 1.3758 - val_loss: 1.3758 - val_top_3_accuracy: 0.8353 - learning_rate: 0.0020
# Restoring model weights from the end of the best epoch: 3.
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
# Accuracy: 0.6501176470588236
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.66      0.76       106
#            1       0.66      0.74      0.70        99
#            2       0.56      0.67      0.61        96
#            3       0.94      0.68      0.79       107
#            4       0.58      0.47      0.52       104
#            5       0.90      0.56      0.69       126
#            6       0.80      0.79      0.80       101
#            7       0.87      0.83      0.85        89
#            8       0.77      0.63      0.69       108
#            9       0.50      0.46      0.48        79
#           10       0.89      0.56      0.69       111
#           11       0.69      0.77      0.73        87
#           12       0.63      0.66      0.64        88
#           13       0.83      0.69      0.75       100
#           14       0.71      0.64      0.67       105
#           15       0.87      0.71      0.78       111
#           16       0.82      0.55      0.66       106
#           17       0.50      0.70      0.59        90
#           18       0.76      0.58      0.66       103
#           19       0.75      0.55      0.64       110
#           20       0.57      0.69      0.63       110
#           21       0.44      0.65      0.52        98
#           22       0.41      0.34      0.37       102
#           23       0.54      0.72      0.62       105
#           24       0.46      0.73      0.56        92
#           25       0.91      0.63      0.74       108
#           26       0.54      0.82      0.65       107
#           27       0.56      0.43      0.49       100
#           28       0.68      0.63      0.66       120
#           29       0.89      0.67      0.76        99
#           30       0.49      0.22      0.31       112
#           31       0.48      0.28      0.36       109
#           32       0.40      0.59      0.48       118
#           33       0.42      0.57      0.48       104
#           34       0.60      0.72      0.65        86
#           35       0.74      0.77      0.75       109
#           36       0.67      0.45      0.54        93
#           37       0.89      0.79      0.84        82
#           38       0.62      0.57      0.59       111
#           39       0.42      0.73      0.53        95
#           40       0.61      0.63      0.62        91
#           41       0.63      0.57      0.60       113
#           42       0.62      0.76      0.68        88
#           43       0.56      0.61      0.59        87
#           44       0.72      0.63      0.67       105
#           45       0.71      0.62      0.66        98
#           46       0.35      0.36      0.36        97
#           47       0.47      0.59      0.52        95
#           48       0.83      0.90      0.86       102
#           49       0.60      0.88      0.71       115
#           50       0.42      0.64      0.51       107
#           51       0.62      0.91      0.74       110
#           52       0.40      0.63      0.49       101
#           53       0.92      0.76      0.83       105
#           54       0.89      0.75      0.81        99
#           55       0.19      0.55      0.28        88
#           56       0.90      0.72      0.80       104
#           57       0.93      0.69      0.79       108
#           58       0.81      0.60      0.69       116
#           59       0.55      0.80      0.65       112
#           60       0.57      0.63      0.60        86
#           61       0.77      0.78      0.77       101
#           62       0.89      0.72      0.79       123
#           63       0.73      0.64      0.68        89
#           64       0.82      0.76      0.79       107
#           65       0.61      0.64      0.63       107
#           66       0.62      0.51      0.56        93
#           67       0.90      0.88      0.89        96
#           68       0.79      0.76      0.77        92
#           69       0.83      0.66      0.74        86
#           70       0.61      0.83      0.70       103
#           71       0.75      0.34      0.46       107
#           72       0.82      0.69      0.75       105
#           73       0.86      0.59      0.70       121
#           74       0.45      0.39      0.42        95
#           75       0.60      0.68      0.64       119
#           76       0.63      0.61      0.62        93
#           77       0.75      0.74      0.75       101
#           78       0.37      0.22      0.27        93
#           79       0.78      0.70      0.74        99
#           80       0.40      0.62      0.49        93
#           81       0.83      0.72      0.77       118
#           82       0.35      0.47      0.40        94
#           83       0.66      0.62      0.64       104
#           84       0.91      0.81      0.86       101
#           85       0.62      0.79      0.70       107
#           86       0.38      0.56      0.45       101
#           87       0.92      0.76      0.84        93
#           88       0.53      0.48      0.51       114
#           89       0.38      0.56      0.45        85
#           90       0.64      0.24      0.35        86
#           91       0.81      0.42      0.55       112
#           92       0.81      0.79      0.80        99
#           93       0.78      0.78      0.78        92
#           94       0.43      0.32      0.36       101
#           95       0.38      0.64      0.48        89
#           96       0.75      0.75      0.75       109
#           97       0.65      0.69      0.67       104
#           98       0.50      0.63      0.56        99
#           99       0.78      0.64      0.70        77
#          100       0.75      0.73      0.74        90
#          101       0.68      0.66      0.67       102
#          102       0.76      0.64      0.69       108
#          103       0.92      0.89      0.91       102
#          104       0.54      0.40      0.46       104
#          105       0.83      0.84      0.83       114
#          106       0.84      0.77      0.80        99
#          107       0.71      0.65      0.68       110
#          108       0.82      0.54      0.65       100
#          109       0.70      0.66      0.68       111
#          110       0.48      0.78      0.59        96
#          111       0.65      0.73      0.69        97
#          112       0.45      0.74      0.56       107
#          113       0.60      0.72      0.66        97
#          114       0.58      0.60      0.59       106
#          115       0.89      0.75      0.81        91
#          116       0.83      0.62      0.71       115
#          117       0.79      0.77      0.78        99
#          118       0.79      0.34      0.48        99
#          119       0.82      0.55      0.66       110
#          120       0.83      0.77      0.80        87
#          121       0.68      0.59      0.63       106
#          122       0.70      0.65      0.67        96
#          123       0.93      0.74      0.82       101
#          124       0.43      0.45      0.44        97
#          125       0.64      0.78      0.70        96
#          126       0.44      0.62      0.52        88
#          127       0.35      0.30      0.33       116
#          128       0.78      0.79      0.78        96
#          129       0.53      0.68      0.59        96
#          130       0.65      0.57      0.60        92
#          131       0.79      0.39      0.52        96
#          132       0.64      0.68      0.66       114
#          133       0.47      0.75      0.58       101
#          134       0.67      0.77      0.72        96
#          135       0.76      0.68      0.72        90
#          136       0.77      0.71      0.74        92
#          137       0.76      0.81      0.78       101
#          138       0.71      0.75      0.73       100
#          139       0.99      0.88      0.93        89
#          140       0.67      0.84      0.75       107
#          141       0.82      0.80      0.81       122
#          142       0.67      0.65      0.66        92
#          143       0.79      0.41      0.54        92
#          144       0.54      0.44      0.49        90
#          145       0.54      0.65      0.59       103
#          146       0.68      0.78      0.73        98
#          147       0.36      0.88      0.52        84
#          148       0.87      0.64      0.74       104
#          149       0.73      0.51      0.60       120
#          150       0.51      0.44      0.47        91
#          151       0.90      0.91      0.91        89
#          152       0.81      0.62      0.70        93
#          153       0.79      0.83      0.81       102
#          154       0.27      0.32      0.29        87
#          155       0.85      0.90      0.87        97
#          156       0.61      0.74      0.67        98
#          157       0.85      0.75      0.80       104
#          158       0.87      0.67      0.76       103
#          159       0.41      0.79      0.54        71
#          160       0.32      0.72      0.44        93
#          161       0.58      0.71      0.64        98
#          162       0.94      0.91      0.93       104
#          163       0.63      0.40      0.49        96
#          164       0.74      0.58      0.65       103
#          165       0.81      0.62      0.71       104
#          166       0.64      0.41      0.50       119
#          167       0.61      0.87      0.72        77
#          168       0.34      0.78      0.47        97
#          169       0.88      0.59      0.70       121
#          170       0.57      0.92      0.70       115
#          171       0.55      0.78      0.65        93
#          172       0.87      0.42      0.57        97
#          173       0.67      0.38      0.48        95
#          174       0.65      0.84      0.73       110
#          175       0.65      0.82      0.73        90
#          176       0.77      0.54      0.63        99
#          177       0.39      0.15      0.22       100
#          178       0.66      0.33      0.44        81
#          179       0.74      0.65      0.69        78
#          180       0.92      0.70      0.79        93
#          181       0.64      0.63      0.64        92
#          182       0.75      0.72      0.73       109
#          183       0.57      0.47      0.51        98
#          184       0.62      0.59      0.61       100
#          185       0.79      0.46      0.58        97
#          186       0.60      0.50      0.55       109
#          187       0.87      0.79      0.83       107
#          188       0.74      0.41      0.53       111
#          189       0.68      0.66      0.67       101
#          190       0.72      0.68      0.70       111
#          191       0.57      0.30      0.39       104
#          192       0.85      0.84      0.85       116
#          193       0.66      0.55      0.60        86
#          194       0.72      0.59      0.65       106
#          195       0.78      0.47      0.59        89
#          196       0.47      0.68      0.56        88
#          197       0.72      0.61      0.66       117
#          198       0.62      0.94      0.75       103
#          199       0.82      0.51      0.63        96
#          200       0.30      0.69      0.42        91
#          201       0.68      0.71      0.69        86
#          202       0.57      0.58      0.57        83
#          203       0.64      0.67      0.65       102
#          204       0.62      0.86      0.72       108
#          205       0.39      0.80      0.52        95
#          206       0.83      0.79      0.81        91
#          207       0.56      0.83      0.67        87
#          208       0.91      0.69      0.78       108
#          209       0.58      0.50      0.54        84
#          210       0.37      0.58      0.45        91
#          211       0.83      0.56      0.67        95
#          212       0.86      0.59      0.70        83
#          213       0.75      0.53      0.62        83
#          214       0.58      0.55      0.56        95
#          215       0.70      0.69      0.70       101
#          216       0.60      0.54      0.57       106
#          217       0.65      0.52      0.57        99
#          218       0.73      0.70      0.72        90
#          219       0.75      0.55      0.64        98
#          220       0.69      0.50      0.58       105
#          221       0.78      0.87      0.82        92
#          222       0.51      0.76      0.61        99
#          223       0.81      0.45      0.58        94
#          224       0.76      0.59      0.67        91
#          225       0.57      0.31      0.40       111
#          226       0.27      0.30      0.28        84
#          227       0.97      0.74      0.84       115
#          228       0.54      0.62      0.58       100
#          229       0.55      0.65      0.60       107
#          230       0.75      0.51      0.61       120
#          231       0.71      0.58      0.64        98
#          232       0.82      0.63      0.71        97
#          233       0.42      0.52      0.46       101
#          234       0.73      0.60      0.66       106
#          235       0.93      0.81      0.86        98
#          236       0.69      0.96      0.80        99
#          237       0.70      0.64      0.67       102
#          238       0.55      0.72      0.62        99
#          239       0.72      0.37      0.49        89
#          240       0.62      0.57      0.59        93
#          241       0.55      0.69      0.62       110
#          242       0.96      0.74      0.84       104
#          243       0.91      0.66      0.77       107
#          244       0.49      0.48      0.48        92
#          245       0.68      0.82      0.75       125
#          246       0.68      0.75      0.72       110
#          247       0.43      0.66      0.52       113
#          248       0.91      0.78      0.84       111
#          249       0.80      0.54      0.65        81
#          250       0.70      0.70      0.70       103
#          251       0.60      0.69      0.64        90
#          252       0.66      0.72      0.69       117
#          253       0.69      0.60      0.64        93
#          254       0.76      0.81      0.78       104
#          255       0.80      0.64      0.71        86
#          256       0.76      0.63      0.69       101
#          257       0.90      0.55      0.68       114
#          258       0.50      0.76      0.60        90
#          259       0.85      0.82      0.83        94
#          260       0.84      0.89      0.87       101
#          261       0.45      0.63      0.53        90
#          262       0.51      0.59      0.55        92
#          263       0.83      0.54      0.66        83
#          264       0.66      0.87      0.75        95
#          265       0.66      0.58      0.62       105
#          266       0.84      0.61      0.71       100
#          267       0.84      0.84      0.84       102
#          268       0.87      0.83      0.85        90
#          269       0.53      0.60      0.57        96
#          270       0.70      0.76      0.73        86
#          271       0.62      0.62      0.62       110
#          272       0.59      0.89      0.71        96
#          273       0.86      0.44      0.58        95
#          274       0.38      0.80      0.52       113
#          275       0.72      0.86      0.78       101
#          276       0.49      0.35      0.41       105
#          277       0.73      0.63      0.67        89
#          278       0.96      0.87      0.91       106
#          279       0.99      0.87      0.92       119
#          280       0.54      0.36      0.43        99
#          281       0.40      0.69      0.51        99
#          282       0.86      0.63      0.73        81
#          283       0.85      0.68      0.75        99
#          284       0.93      0.74      0.82       101
#          285       0.63      0.48      0.54        92
#          286       0.80      0.87      0.83        83
#          287       0.63      0.71      0.67        93
#          288       0.46      0.40      0.43        95
#          289       0.71      0.70      0.70       115
#          290       0.64      0.68      0.66       107
#          291       0.97      0.84      0.90       103
#          292       0.54      0.67      0.60        96
#          293       0.82      0.45      0.58       108
#          294       0.90      0.88      0.89       108
#          295       0.83      0.77      0.80        83
#          296       0.84      0.86      0.85        87
#          297       0.61      0.77      0.68        91
#          298       0.85      0.76      0.80       102
#          299       0.76      0.47      0.58       100
#          300       0.64      0.59      0.61        97
#          301       0.83      0.84      0.84       103
#          302       0.69      0.84      0.76       101
#          303       0.92      0.74      0.82       107
#          304       0.65      0.96      0.77        96
#          305       0.30      0.47      0.36        87
#          306       0.72      0.85      0.78       111
#          307       0.63      0.41      0.50        95
#          308       0.54      0.69      0.60       103
#          309       0.64      0.58      0.61       107
#          310       0.76      0.73      0.74       110
#          311       0.89      0.68      0.77        96
#          312       0.62      0.83      0.71       108
#          313       0.52      0.33      0.40       102
#          314       0.57      0.86      0.68       100
#          315       0.58      0.77      0.66        93
#          316       0.66      0.83      0.74       109
#          317       0.43      0.55      0.48        95
#          318       0.83      0.55      0.66        96
#          319       0.90      0.95      0.92        93
#          320       0.68      0.36      0.47       135
#          321       0.59      0.28      0.38       114
#          322       0.50      0.68      0.58        98
#          323       0.84      0.88      0.86       108
#          324       0.65      0.72      0.68        95
#          325       0.61      0.41      0.49       107
#          326       0.76      0.58      0.66        98
#          327       0.68      0.25      0.37        91
#          328       0.79      0.72      0.75       114
#          329       0.48      0.67      0.56       101
#          330       0.45      0.62      0.52       111
#          331       0.71      0.65      0.68       100
#          332       0.78      0.52      0.62       113
#          333       0.75      0.73      0.74        86
#          334       0.77      0.80      0.79       120
#          335       0.93      0.81      0.86       109
#          336       0.82      0.69      0.75        80
#          337       0.78      0.43      0.55        98
#          338       0.69      0.79      0.74        98
#          339       0.77      0.66      0.71       100
#
#     accuracy                           0.65     34000
#    macro avg       0.68      0.65      0.65     34000
# weighted avg       0.68      0.65      0.65     34000
#
# Confusion Matrix:
# [[70  0  0 ...  0  0  0]
#  [ 0 73  0 ...  0  0  0]
#  [ 0  0 64 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 42  0  0]
#  [ 0  0  0 ...  0 77  0]
#  [ 0  0  0 ...  0  0 66]]
# 2025/04/05 01:04:57 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpw85lwapc/model/model.pkl, flavor: sklearn). Fall back to return ['scikit-learn==1.6.1', 'cloudpickle==3.1.1']. Set logging level to DEBUG to see the full traceback.
# 2025/04/05 01:04:57 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Mobilenet logged with accuracy: 0.6501

# %%
# callbacks = [
#     ReduceLROnPlateau(monitor='val_top_3_accuracy', factor=0.75, patience=3, min_delta=0.001,
#                           mode='max', min_lr=1e-5, verbose=1),
#     ModelCheckpoint('doodlemind_model.weights.h5', monitor='val_top_3_accuracy', mode='max', save_best_only=True,
#                     save_weights_only=True, save_freq='epoch', verbose=1),
#     EarlyStopping(monitor='val_top_3_accuracy', min_delta=0.001, patience=5,
#                   restore_best_weights=True, mode='max', verbose=1)
# ]
# hists = []
# hist = model.fit(
#     train_datagen, steps_per_epoch=STEPS, epochs=40, verbose=1,
#     validation_data=(x_valid, y_valid),
#     callbacks = callbacks
# )
# hists.append(hist)
# Out:
# Epoch 1/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - categorical_accuracy: 0.2233 - categorical_crossentropy: 3.7852 - loss: 3.7852 - top_3_accuracy: 0.3617
# Epoch 1: val_top_3_accuracy improved from -inf to 0.61821, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 314s 345ms/step - categorical_accuracy: 0.2235 - categorical_crossentropy: 3.7839 - loss: 3.7839 - top_3_accuracy: 0.3619 - val_categorical_accuracy: 0.4048 - val_categorical_crossentropy: 2.7648 - val_loss: 2.7648 - val_top_3_accuracy: 0.6182 - learning_rate: 0.0020
# Epoch 2/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - categorical_accuracy: 0.5717 - categorical_crossentropy: 1.7330 - loss: 1.7330 - top_3_accuracy: 0.7733
# Epoch 2: val_top_3_accuracy improved from 0.61821 to 0.72279, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 280s 350ms/step - categorical_accuracy: 0.5717 - categorical_crossentropy: 1.7329 - loss: 1.7329 - top_3_accuracy: 0.7733 - val_categorical_accuracy: 0.5037 - val_categorical_crossentropy: 2.1019 - val_loss: 2.1019 - val_top_3_accuracy: 0.7228 - learning_rate: 0.0020
# Epoch 3/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - categorical_accuracy: 0.6319 - categorical_crossentropy: 1.4641 - loss: 1.4641 - top_3_accuracy: 0.8197
# Epoch 3: val_top_3_accuracy improved from 0.72279 to 0.78656, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 277s 347ms/step - categorical_accuracy: 0.6319 - categorical_crossentropy: 1.4641 - loss: 1.4641 - top_3_accuracy: 0.8197 - val_categorical_accuracy: 0.5870 - val_categorical_crossentropy: 1.6744 - val_loss: 1.6744 - val_top_3_accuracy: 0.7866 - learning_rate: 0.0020
# Epoch 4/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - categorical_accuracy: 0.6595 - categorical_crossentropy: 1.3508 - loss: 1.3508 - top_3_accuracy: 0.8391
# Epoch 4: val_top_3_accuracy improved from 0.78656 to 0.79771, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 275s 344ms/step - categorical_accuracy: 0.6595 - categorical_crossentropy: 1.3508 - loss: 1.3508 - top_3_accuracy: 0.8391 - val_categorical_accuracy: 0.5957 - val_categorical_crossentropy: 1.6251 - val_loss: 1.6251 - val_top_3_accuracy: 0.7977 - learning_rate: 0.0020
# Epoch 5/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - categorical_accuracy: 0.6774 - categorical_crossentropy: 1.2777 - loss: 1.2777 - top_3_accuracy: 0.8508
# Epoch 5: val_top_3_accuracy did not improve from 0.79771
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 266s 332ms/step - categorical_accuracy: 0.6774 - categorical_crossentropy: 1.2777 - loss: 1.2777 - top_3_accuracy: 0.8508 - val_categorical_accuracy: 0.2302 - val_categorical_crossentropy: 4.3796 - val_loss: 4.3796 - val_top_3_accuracy: 0.3899 - learning_rate: 0.0020
# Epoch 6/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - categorical_accuracy: 0.6868 - categorical_crossentropy: 1.2289 - loss: 1.2289 - top_3_accuracy: 0.8589
# Epoch 6: val_top_3_accuracy improved from 0.79771 to 0.82365, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 269s 337ms/step - categorical_accuracy: 0.6868 - categorical_crossentropy: 1.2289 - loss: 1.2289 - top_3_accuracy: 0.8589 - val_categorical_accuracy: 0.6368 - val_categorical_crossentropy: 1.4570 - val_loss: 1.4570 - val_top_3_accuracy: 0.8236 - learning_rate: 0.0020
# Epoch 7/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - categorical_accuracy: 0.6988 - categorical_crossentropy: 1.1813 - loss: 1.1813 - top_3_accuracy: 0.8661
# Epoch 7: val_top_3_accuracy improved from 0.82365 to 0.85479, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 237s 296ms/step - categorical_accuracy: 0.6988 - categorical_crossentropy: 1.1813 - loss: 1.1813 - top_3_accuracy: 0.8661 - val_categorical_accuracy: 0.6782 - val_categorical_crossentropy: 1.2694 - val_loss: 1.2694 - val_top_3_accuracy: 0.8548 - learning_rate: 0.0020
# Epoch 8/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - categorical_accuracy: 0.7089 - categorical_crossentropy: 1.1416 - loss: 1.1416 - top_3_accuracy: 0.8727
# Epoch 8: val_top_3_accuracy did not improve from 0.85479
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 275s 344ms/step - categorical_accuracy: 0.7089 - categorical_crossentropy: 1.1416 - loss: 1.1416 - top_3_accuracy: 0.8727 - val_categorical_accuracy: 0.6594 - val_categorical_crossentropy: 1.3430 - val_loss: 1.3430 - val_top_3_accuracy: 0.8419 - learning_rate: 0.0020
# Epoch 9/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - categorical_accuracy: 0.7119 - categorical_crossentropy: 1.1265 - loss: 1.1265 - top_3_accuracy: 0.8738
# Epoch 9: val_top_3_accuracy did not improve from 0.85479
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 244s 305ms/step - categorical_accuracy: 0.7119 - categorical_crossentropy: 1.1265 - loss: 1.1265 - top_3_accuracy: 0.8738 - val_categorical_accuracy: 0.5820 - val_categorical_crossentropy: 1.6723 - val_loss: 1.6723 - val_top_3_accuracy: 0.7874 - learning_rate: 0.0020
# Epoch 10/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - categorical_accuracy: 0.7068 - categorical_crossentropy: 1.1485 - loss: 1.1485 - top_3_accuracy: 0.8702
# Epoch 10: val_top_3_accuracy improved from 0.85479 to 0.86112, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 235s 294ms/step - categorical_accuracy: 0.7068 - categorical_crossentropy: 1.1485 - loss: 1.1485 - top_3_accuracy: 0.8702 - val_categorical_accuracy: 0.6883 - val_categorical_crossentropy: 1.2166 - val_loss: 1.2166 - val_top_3_accuracy: 0.8611 - learning_rate: 0.0020
# Epoch 11/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - categorical_accuracy: 0.7251 - categorical_crossentropy: 1.0714 - loss: 1.0714 - top_3_accuracy: 0.8828
# Epoch 11: val_top_3_accuracy improved from 0.86112 to 0.87579, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 306s 382ms/step - categorical_accuracy: 0.7251 - categorical_crossentropy: 1.0714 - loss: 1.0714 - top_3_accuracy: 0.8828 - val_categorical_accuracy: 0.7099 - val_categorical_crossentropy: 1.1217 - val_loss: 1.1217 - val_top_3_accuracy: 0.8758 - learning_rate: 0.0020
# Epoch 12/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - categorical_accuracy: 0.7266 - categorical_crossentropy: 1.0686 - loss: 1.0686 - top_3_accuracy: 0.8821
# Epoch 12: val_top_3_accuracy improved from 0.87579 to 0.87679, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 262s 327ms/step - categorical_accuracy: 0.7266 - categorical_crossentropy: 1.0686 - loss: 1.0686 - top_3_accuracy: 0.8821 - val_categorical_accuracy: 0.7137 - val_categorical_crossentropy: 1.1137 - val_loss: 1.1137 - val_top_3_accuracy: 0.8768 - learning_rate: 0.0020
# Epoch 13/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - categorical_accuracy: 0.7250 - categorical_crossentropy: 1.0713 - loss: 1.0713 - top_3_accuracy: 0.8822
# Epoch 13: val_top_3_accuracy improved from 0.87679 to 0.88647, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 252s 315ms/step - categorical_accuracy: 0.7250 - categorical_crossentropy: 1.0713 - loss: 1.0713 - top_3_accuracy: 0.8822 - val_categorical_accuracy: 0.7274 - val_categorical_crossentropy: 1.0590 - val_loss: 1.0590 - val_top_3_accuracy: 0.8865 - learning_rate: 0.0020
# Epoch 14/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - categorical_accuracy: 0.7373 - categorical_crossentropy: 1.0253 - loss: 1.0253 - top_3_accuracy: 0.8888
# Epoch 14: val_top_3_accuracy did not improve from 0.88647
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 258s 323ms/step - categorical_accuracy: 0.7373 - categorical_crossentropy: 1.0253 - loss: 1.0253 - top_3_accuracy: 0.8888 - val_categorical_accuracy: 0.7239 - val_categorical_crossentropy: 1.0743 - val_loss: 1.0743 - val_top_3_accuracy: 0.8819 - learning_rate: 0.0020
# Epoch 15/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - categorical_accuracy: 0.7445 - categorical_crossentropy: 0.9875 - loss: 0.9875 - top_3_accuracy: 0.8947
# Epoch 15: val_top_3_accuracy improved from 0.88647 to 0.88724, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 166s 208ms/step - categorical_accuracy: 0.7445 - categorical_crossentropy: 0.9875 - loss: 0.9875 - top_3_accuracy: 0.8947 - val_categorical_accuracy: 0.7274 - val_categorical_crossentropy: 1.0525 - val_loss: 1.0525 - val_top_3_accuracy: 0.8872 - learning_rate: 0.0020
# Epoch 16/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - categorical_accuracy: 0.7476 - categorical_crossentropy: 0.9759 - loss: 0.9759 - top_3_accuracy: 0.8959
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.001500000071246177.
#
# Epoch 16: val_top_3_accuracy did not improve from 0.88724
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 161s 201ms/step - categorical_accuracy: 0.7476 - categorical_crossentropy: 0.9759 - loss: 0.9759 - top_3_accuracy: 0.8959 - val_categorical_accuracy: 0.7321 - val_categorical_crossentropy: 1.0428 - val_loss: 1.0428 - val_top_3_accuracy: 0.8862 - learning_rate: 0.0020
# Epoch 17/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - categorical_accuracy: 0.7525 - categorical_crossentropy: 0.9579 - loss: 0.9579 - top_3_accuracy: 0.8985
# Epoch 17: val_top_3_accuracy improved from 0.88724 to 0.89688, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 162s 202ms/step - categorical_accuracy: 0.7525 - categorical_crossentropy: 0.9579 - loss: 0.9579 - top_3_accuracy: 0.8985 - val_categorical_accuracy: 0.7459 - val_categorical_crossentropy: 0.9809 - val_loss: 0.9809 - val_top_3_accuracy: 0.8969 - learning_rate: 0.0015
# Epoch 18/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - categorical_accuracy: 0.7541 - categorical_crossentropy: 0.9546 - loss: 0.9546 - top_3_accuracy: 0.8990
# Epoch 18: val_top_3_accuracy did not improve from 0.89688
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 163s 204ms/step - categorical_accuracy: 0.7541 - categorical_crossentropy: 0.9546 - loss: 0.9546 - top_3_accuracy: 0.8990 - val_categorical_accuracy: 0.7424 - val_categorical_crossentropy: 1.0003 - val_loss: 1.0003 - val_top_3_accuracy: 0.8927 - learning_rate: 0.0015
# Epoch 19/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - categorical_accuracy: 0.7528 - categorical_crossentropy: 0.9533 - loss: 0.9533 - top_3_accuracy: 0.8987
# Epoch 19: val_top_3_accuracy did not improve from 0.89688
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 164s 205ms/step - categorical_accuracy: 0.7528 - categorical_crossentropy: 0.9533 - loss: 0.9533 - top_3_accuracy: 0.8987 - val_categorical_accuracy: 0.7503 - val_categorical_crossentropy: 0.9710 - val_loss: 0.9710 - val_top_3_accuracy: 0.8957 - learning_rate: 0.0015
# Epoch 20/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - categorical_accuracy: 0.7560 - categorical_crossentropy: 0.9475 - loss: 0.9475 - top_3_accuracy: 0.9006
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.001125000009778887.
#
# Epoch 20: val_top_3_accuracy did not improve from 0.89688
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 162s 202ms/step - categorical_accuracy: 0.7560 - categorical_crossentropy: 0.9475 - loss: 0.9475 - top_3_accuracy: 0.9006 - val_categorical_accuracy: 0.7458 - val_categorical_crossentropy: 0.9735 - val_loss: 0.9735 - val_top_3_accuracy: 0.8960 - learning_rate: 0.0015
# Epoch 21/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - categorical_accuracy: 0.7615 - categorical_crossentropy: 0.9227 - loss: 0.9227 - top_3_accuracy: 0.9028
# Epoch 21: val_top_3_accuracy did not improve from 0.89688
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 165s 206ms/step - categorical_accuracy: 0.7615 - categorical_crossentropy: 0.9226 - loss: 0.9226 - top_3_accuracy: 0.9028 - val_categorical_accuracy: 0.6794 - val_categorical_crossentropy: 1.2560 - val_loss: 1.2560 - val_top_3_accuracy: 0.8549 - learning_rate: 0.0011
# Epoch 22/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - categorical_accuracy: 0.7650 - categorical_crossentropy: 0.9086 - loss: 0.9086 - top_3_accuracy: 0.9056
# Epoch 22: val_top_3_accuracy improved from 0.89688 to 0.90329, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 165s 206ms/step - categorical_accuracy: 0.7650 - categorical_crossentropy: 0.9086 - loss: 0.9086 - top_3_accuracy: 0.9056 - val_categorical_accuracy: 0.7610 - val_categorical_crossentropy: 0.9277 - val_loss: 0.9277 - val_top_3_accuracy: 0.9033 - learning_rate: 0.0011
# Epoch 23/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - categorical_accuracy: 0.7647 - categorical_crossentropy: 0.9105 - loss: 0.9105 - top_3_accuracy: 0.9049
# Epoch 23: val_top_3_accuracy did not improve from 0.90329
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 162s 203ms/step - categorical_accuracy: 0.7647 - categorical_crossentropy: 0.9105 - loss: 0.9105 - top_3_accuracy: 0.9049 - val_categorical_accuracy: 0.7600 - val_categorical_crossentropy: 0.9250 - val_loss: 0.9250 - val_top_3_accuracy: 0.9023 - learning_rate: 0.0011
# Epoch 24/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - categorical_accuracy: 0.7688 - categorical_crossentropy: 0.8926 - loss: 0.8926 - top_3_accuracy: 0.9072
# Epoch 24: val_top_3_accuracy improved from 0.90329 to 0.90406, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 162s 203ms/step - categorical_accuracy: 0.7688 - categorical_crossentropy: 0.8927 - loss: 0.8927 - top_3_accuracy: 0.9072 - val_categorical_accuracy: 0.7615 - val_categorical_crossentropy: 0.9138 - val_loss: 0.9138 - val_top_3_accuracy: 0.9041 - learning_rate: 0.0011
# Epoch 25/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - categorical_accuracy: 0.7695 - categorical_crossentropy: 0.8893 - loss: 0.8893 - top_3_accuracy: 0.9079
# Epoch 25: val_top_3_accuracy improved from 0.90406 to 0.90503, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 165s 206ms/step - categorical_accuracy: 0.7695 - categorical_crossentropy: 0.8893 - loss: 0.8893 - top_3_accuracy: 0.9079 - val_categorical_accuracy: 0.7610 - val_categorical_crossentropy: 0.9156 - val_loss: 0.9156 - val_top_3_accuracy: 0.9050 - learning_rate: 0.0011
# Epoch 26/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - categorical_accuracy: 0.7699 - categorical_crossentropy: 0.8866 - loss: 0.8866 - top_3_accuracy: 0.9080
# Epoch 26: val_top_3_accuracy did not improve from 0.90503
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 168s 209ms/step - categorical_accuracy: 0.7699 - categorical_crossentropy: 0.8866 - loss: 0.8866 - top_3_accuracy: 0.9080 - val_categorical_accuracy: 0.7642 - val_categorical_crossentropy: 0.9157 - val_loss: 0.9157 - val_top_3_accuracy: 0.9045 - learning_rate: 0.0011
# Epoch 27/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - categorical_accuracy: 0.7676 - categorical_crossentropy: 0.9001 - loss: 0.9001 - top_3_accuracy: 0.9069
# Epoch 27: val_top_3_accuracy improved from 0.90503 to 0.90644, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 169s 211ms/step - categorical_accuracy: 0.7676 - categorical_crossentropy: 0.9001 - loss: 0.9001 - top_3_accuracy: 0.9069 - val_categorical_accuracy: 0.7656 - val_categorical_crossentropy: 0.9022 - val_loss: 0.9022 - val_top_3_accuracy: 0.9064 - learning_rate: 0.0011
# Epoch 28/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - categorical_accuracy: 0.7703 - categorical_crossentropy: 0.8827 - loss: 0.8827 - top_3_accuracy: 0.9087
# Epoch 28: val_top_3_accuracy did not improve from 0.90644
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 166s 208ms/step - categorical_accuracy: 0.7703 - categorical_crossentropy: 0.8827 - loss: 0.8827 - top_3_accuracy: 0.9087 - val_categorical_accuracy: 0.7650 - val_categorical_crossentropy: 0.9096 - val_loss: 0.9096 - val_top_3_accuracy: 0.9057 - learning_rate: 0.0011
# Epoch 29/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - categorical_accuracy: 0.7805 - categorical_crossentropy: 0.8388 - loss: 0.8388 - top_3_accuracy: 0.9142
# Epoch 29: val_top_3_accuracy improved from 0.90644 to 0.90656, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 167s 209ms/step - categorical_accuracy: 0.7805 - categorical_crossentropy: 0.8388 - loss: 0.8388 - top_3_accuracy: 0.9142 - val_categorical_accuracy: 0.7657 - val_categorical_crossentropy: 0.9016 - val_loss: 0.9016 - val_top_3_accuracy: 0.9066 - learning_rate: 0.0011
# Epoch 30/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - categorical_accuracy: 0.7802 - categorical_crossentropy: 0.8415 - loss: 0.8415 - top_3_accuracy: 0.9142
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0008437499636784196.
#
# Epoch 30: val_top_3_accuracy did not improve from 0.90656
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 166s 207ms/step - categorical_accuracy: 0.7802 - categorical_crossentropy: 0.8415 - loss: 0.8415 - top_3_accuracy: 0.9142 - val_categorical_accuracy: 0.7631 - val_categorical_crossentropy: 0.9131 - val_loss: 0.9131 - val_top_3_accuracy: 0.9044 - learning_rate: 0.0011
# Epoch 31/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - categorical_accuracy: 0.7818 - categorical_crossentropy: 0.8337 - loss: 0.8337 - top_3_accuracy: 0.9155
# Epoch 31: val_top_3_accuracy improved from 0.90656 to 0.90876, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 171s 213ms/step - categorical_accuracy: 0.7818 - categorical_crossentropy: 0.8337 - loss: 0.8337 - top_3_accuracy: 0.9155 - val_categorical_accuracy: 0.7712 - val_categorical_crossentropy: 0.8807 - val_loss: 0.8807 - val_top_3_accuracy: 0.9088 - learning_rate: 8.4375e-04
# Epoch 32/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - categorical_accuracy: 0.7844 - categorical_crossentropy: 0.8251 - loss: 0.8251 - top_3_accuracy: 0.9162
# Epoch 32: val_top_3_accuracy did not improve from 0.90876
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 166s 207ms/step - categorical_accuracy: 0.7844 - categorical_crossentropy: 0.8251 - loss: 0.8251 - top_3_accuracy: 0.9162 - val_categorical_accuracy: 0.7720 - val_categorical_crossentropy: 0.8772 - val_loss: 0.8772 - val_top_3_accuracy: 0.9081 - learning_rate: 8.4375e-04
# Epoch 33/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - categorical_accuracy: 0.7869 - categorical_crossentropy: 0.8159 - loss: 0.8159 - top_3_accuracy: 0.9178
# Epoch 33: val_top_3_accuracy improved from 0.90876 to 0.90944, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 166s 208ms/step - categorical_accuracy: 0.7869 - categorical_crossentropy: 0.8159 - loss: 0.8159 - top_3_accuracy: 0.9178 - val_categorical_accuracy: 0.7736 - val_categorical_crossentropy: 0.8768 - val_loss: 0.8768 - val_top_3_accuracy: 0.9094 - learning_rate: 8.4375e-04
# Epoch 34/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - categorical_accuracy: 0.7830 - categorical_crossentropy: 0.8294 - loss: 0.8294 - top_3_accuracy: 0.9153
# Epoch 34: val_top_3_accuracy improved from 0.90944 to 0.91053, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 165s 206ms/step - categorical_accuracy: 0.7830 - categorical_crossentropy: 0.8294 - loss: 0.8294 - top_3_accuracy: 0.9153 - val_categorical_accuracy: 0.7747 - val_categorical_crossentropy: 0.8668 - val_loss: 0.8668 - val_top_3_accuracy: 0.9105 - learning_rate: 8.4375e-04
# Epoch 35/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - categorical_accuracy: 0.7844 - categorical_crossentropy: 0.8244 - loss: 0.8244 - top_3_accuracy: 0.9157
# Epoch 35: val_top_3_accuracy did not improve from 0.91053
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 168s 211ms/step - categorical_accuracy: 0.7844 - categorical_crossentropy: 0.8244 - loss: 0.8244 - top_3_accuracy: 0.9157 - val_categorical_accuracy: 0.7731 - val_categorical_crossentropy: 0.8754 - val_loss: 0.8754 - val_top_3_accuracy: 0.9093 - learning_rate: 8.4375e-04
# Epoch 36/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - categorical_accuracy: 0.7847 - categorical_crossentropy: 0.8224 - loss: 0.8224 - top_3_accuracy: 0.9161
# Epoch 36: val_top_3_accuracy improved from 0.91053 to 0.91068, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 168s 211ms/step - categorical_accuracy: 0.7847 - categorical_crossentropy: 0.8224 - loss: 0.8224 - top_3_accuracy: 0.9161 - val_categorical_accuracy: 0.7740 - val_categorical_crossentropy: 0.8717 - val_loss: 0.8717 - val_top_3_accuracy: 0.9107 - learning_rate: 8.4375e-04
# Epoch 37/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - categorical_accuracy: 0.7845 - categorical_crossentropy: 0.8256 - loss: 0.8256 - top_3_accuracy: 0.9162
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0006328124727588147.
#
# Epoch 37: val_top_3_accuracy improved from 0.91068 to 0.91109, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 166s 207ms/step - categorical_accuracy: 0.7845 - categorical_crossentropy: 0.8256 - loss: 0.8256 - top_3_accuracy: 0.9162 - val_categorical_accuracy: 0.7739 - val_categorical_crossentropy: 0.8663 - val_loss: 0.8663 - val_top_3_accuracy: 0.9111 - learning_rate: 8.4375e-04
# Epoch 38/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - categorical_accuracy: 0.7874 - categorical_crossentropy: 0.8181 - loss: 0.8181 - top_3_accuracy: 0.9167
# Epoch 38: val_top_3_accuracy improved from 0.91109 to 0.91353, saving model to doodlemind_model.weights.h5
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 169s 212ms/step - categorical_accuracy: 0.7874 - categorical_crossentropy: 0.8181 - loss: 0.8181 - top_3_accuracy: 0.9167 - val_categorical_accuracy: 0.7810 - val_categorical_crossentropy: 0.8496 - val_loss: 0.8496 - val_top_3_accuracy: 0.9135 - learning_rate: 6.3281e-04
# Epoch 39/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - categorical_accuracy: 0.7880 - categorical_crossentropy: 0.8142 - loss: 0.8142 - top_3_accuracy: 0.9176
# Epoch 39: val_top_3_accuracy did not improve from 0.91353
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 169s 211ms/step - categorical_accuracy: 0.7880 - categorical_crossentropy: 0.8142 - loss: 0.8142 - top_3_accuracy: 0.9176 - val_categorical_accuracy: 0.7794 - val_categorical_crossentropy: 0.8503 - val_loss: 0.8503 - val_top_3_accuracy: 0.9128 - learning_rate: 6.3281e-04
# Epoch 40/40
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - categorical_accuracy: 0.7880 - categorical_crossentropy: 0.8169 - loss: 0.8169 - top_3_accuracy: 0.9174
# Epoch 40: val_top_3_accuracy did not improve from 0.91353
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 167s 209ms/step - categorical_accuracy: 0.7880 - categorical_crossentropy: 0.8169 - loss: 0.8169 - top_3_accuracy: 0.9174 - val_categorical_accuracy: 0.7803 - val_categorical_crossentropy: 0.8447 - val_loss: 0.8447 - val_top_3_accuracy: 0.9131 - learning_rate: 6.3281e-04
# Restoring model weights from the end of the best epoch: 38.

# %%
hist_df = pd.concat([pd.DataFrame(hist.history) for hist in hists], sort=True)
hist_df.index = np.arange(1, len(hist_df)+1)
fig, axs = plt.subplots(nrows=2, sharex=True, figsize=(16, 10))
axs[0].plot(hist_df.val_categorical_accuracy, lw=5, label='Validation Accuracy')
axs[0].plot(hist_df.categorical_accuracy, lw=5, label='Training Accuracy')
axs[0].set_ylabel('Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].grid()
axs[0].legend(loc=0)
axs[1].plot(hist_df.val_categorical_crossentropy, lw=5, label='Validation MLogLoss')
axs[1].plot(hist_df.categorical_crossentropy, lw=5, label='Training MLogLoss')
axs[1].set_ylabel('MLogLoss')
axs[1].set_xlabel('Epoch')
axs[1].grid()
axs[1].legend(loc=0)
fig.savefig('hist.png', dpi=300)
plt.show();

# %%
# valid_predictions = model.predict(x_valid, batch_size=128, verbose=1)
# y_true = valid_df['y'].values
# map3 = mapk(valid_df[['y']].values, preds2catids(valid_predictions).values)
# print('Map3: {:.3f}'.format(map3))

# # calculate metrics
# Out:
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# Map3: 0.839
